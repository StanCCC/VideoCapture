# %%
import cv2
import os
import numpy as np 
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import structural_similarity

VidoePath = './video/lift.mp4'
FrameFrequency = 24 # 每frameFrequency保存一张图片

outPutDirName = './image_data/' # 设置保存路径
Similarity = 0.93


# 获取一个视频打开cap 参数1 file name
#cap = cv2.VideoCapture(0, cv2.CAP_DSHOW) # 摄像头截取
cap = cv2.VideoCapture(VidoePath)
isOpened = cap.isOpened # 判断是否打开‘
print(isOpened)
# 获取信息 宽高
n_frame = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print('总帧数：',n_frame) # 整个视频的总帧数
fps = cap.get(cv2.CAP_PROP_FPS) # 帧率 每秒展示多少张图片
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) # w
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)) # h
print('帧数、宽度、高度分别为：',fps,width,height) # 帧率 宽 高
i = 0 # 记录读取多少帧
k = 0 # 多於兩張圖片時運行
img_files=[]
while(isOpened):
    # 结束标志是否读取到最后一帧
    if i == n_frame:
        break
    else:
        i = i + 1
    (flag,frame) = cap.read() # read方法 读取每一张 flag是否读取成功 frame 读取内容
    fileName = str(i)+'.jpg' # 名字累加
    # 如果文件目录不存在则创建目录
    if not os.path.exists(outPutDirName):
        os.makedirs(outPutDirName)
    if i % FrameFrequency == 0 :
        img_files.append(frame)   
        #print(img_files[-1])   
        k = k + 1
        if k > 2:
            img=img_files[-2]
            img1=img_files[-1]
            ssim=structural_similarity(img, img1, channel_axis=-1,win_size=7)#channel_axis=-1,win_size=7
            if ssim < Similarity:
                print(ssim)
                cv2.imwrite(outPutDirName + fileName, img, [cv2.IMWRITE_JPEG_QUALITY,100])
print('end!')
# Out:
# <built-in method isOpened of cv2.VideoCapture object at 0x0000011A0070F4D0>
# 总帧数： 2472
# 帧数、宽度、高度分别为： 29.97002997002997 1280 720
# 0.9214074223638601
# 0.9054031582440306
# 0.8194446741727924
# 0.829110832114683
# 0.9284514904852696
# 0.8794230286330569
# 0.9021224968405663
# 0.9156471613079716
# 0.8709065561310453
# 0.9091254470171117
# 0.917220982964

# %%
img = cv2.imread('./image_data/2472.jpg')

# %%
img

# %%
import random
li=[random. randint(0,5)]
x=[]
for i in range(30):
    if i > 1:
        li.append(random.randint(0,10))
        if li[-2] != li[-1]:
            x.append(li[-2])

li
# Out:
# [0,
#  10,
#  4,
#  5,
#  5,
#  7,
#  0,
#  10,
#  1,
#  1,
#  7,
#  2,
#  5,
#  5,
#  4,
#  9,
#  7,
#  3,
#  3,
#  7,
#  0,
#  0,
#  9,
#  1,
#  5,
#  1,
#  1,
#  2,
#  9]

# %%
a=['1']

# %%
a[-2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 a[-2]
#
# IndexError: list index out of range

# %%
import os
import cv2
import numpy as np 
#from skimage import compare_ssim
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import structural_similarity
#from skimage.measure import compare_ssim
'''相邻两个文件比较相似度，相似就把第二个加到新列表(删除列表）里，然后进行新列表去重，统一删除。
　　例如：有文件1-10，首先1和2相比较，若相似，则把2加入到新列表里，再接着2和3相比较，若不相似，则继续进行3和4比较...一直比到最后，然后删除新列表里的图片
   只对于连续图片（例一个视频里截下的图片）准确率也较高，其效率高'''
def delete(filename1):
    os.remove(filename1)
if __name__ == '__main__':
    path = r'./image_data/' # 文件所在路径
    img_path = path
    imgs_n = [] # 新建的删除列表
    # i = 0 # 用来统计删了第几张图片
    # img_files = [os.path.join(rootdir, file) for rootdir, _, files in os.walk(path) for file in files if
    #              (file.endswith('.jpg'))] 
    img_files=[]
    for rootdir, _, files in os.walk(path):
        files.sort(key=lambda x:int(x[:-4]))
    for file in files:
         if file.endswith('.jpg'):
            img_files.append(os.path.join(rootdir, file))
   
    for currIndex, filename in enumerate(img_files):
        if not os.path.exists(img_files[currIndex]):
            print('not exist', img_files[currIndex])
            break
        img = cv2.imread(img_files[currIndex])
        img1 = cv2.imread(img_files[currIndex + 1])
        print(type(img))
        print(img.shape)
        # img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        # https://cloud.tencent.com/developer/section/1414961 开发者手册链接
        # 本程序最核心的代码
        # skimage.measure.compare_ssim（X，Y，...）
        # 计算两幅图像之间的平均结构相似性指数
        #ssim = ssim(img, img1,multichannel=True,win_size=7)
        ssim=structural_similarity(img, img1,channel_axis=-1,win_size=7)
        # 相似度大于0.9就加入删除列表
        if ssim > 0.93:
            imgs_n.append(img_files[currIndex + 1]) # 加入新建删除列表
            i = i+1 # 每加入一个就会删除
            print(img_files[currIndex], img_files[currIndex + 1], ssim)
            print('删除次数', i)
        # 否则不删除，给出两图片的相似度
        else:
            print('small_ssim',img_files[currIndex], img_files[currIndex + 1], ssim)
        currIndex += 1
        if currIndex >= len(img_files)-1:
            break
    for image in imgs_n:
        delete(image)
# Out:
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/72.jpg ./image_data/96.jpg 1.0
# 删除次数 2473
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/96.jpg ./image_data/120.jpg 1.0
# 删除次数 2474
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/120.jpg ./image_data/144.jpg 1.0
# 删除次数 2475
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/144.jpg ./image_data/168.jpg 1.0
# 删除次数 2476
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/168.jpg ./image_data/192.jpg 1.0
# 删除次数 2477
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/192.jpg ./image_data/216.jpg 1.0
# 删除次数 2478
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/216.jpg ./image_data/240.jpg 1.0
# 删除次数 2479
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/240.jpg ./image_data/264.jpg 1.0
# 删除次数 2480
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/264.jpg ./image_data/288.jpg 1.0
# 删除次数 2481
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/288.jpg ./image_data/312.jpg 1.0
# 删除次数 2482
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/312.jpg ./image_data/336.jpg 1.0
# 删除次数 2483
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/336.jpg ./image_data/360.jpg 1.0
# 删除次数 2484
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/360.jpg ./image_data/384.jpg 1.0
# 删除次数 2485
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/384.jpg ./image_data/408.jpg 1.0
# 删除次数 2486
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/408.jpg ./image_data/432.jpg 1.0
# 删除次数 2487
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/432.jpg ./image_data/456.jpg 1.0
# 删除次数 2488
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/456.jpg ./image_data/480.jpg 1.0
# 删除次数 2489
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/480.jpg ./image_data/504.jpg 1.0
# 删除次数 2490
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/504.jpg ./image_data/528.jpg 1.0
# 删除次数 2491
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/528.jpg ./image_data/552.jpg 1.0
# 删除次数 2492
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/552.jpg ./image_data/576.jpg 1.0
# 删除次数 2493
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/576.jpg ./image_data/600.jpg 1.0
# 删除次数 2494
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/600.jpg ./image_data/624.jpg 1.0
# 删除次数 2495
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/624.jpg ./image_data/648.jpg 1.0
# 删除次数 2496
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/648.jpg ./image_data/672.jpg 1.0
# 删除次数 2497
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/672.jpg ./image_data/696.jpg 1.0
# 删除次数 2498
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/696.jpg ./image_data/720.jpg 1.0
# 删除次数 2499
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/720.jpg ./image_data/744.jpg 1.0
# 删除次数 2500
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/744.jpg ./image_data/768.jpg 1.0
# 删除次数 2501
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/768.jpg ./image_data/792.jpg 1.0
# 删除次数 2502
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/792.jpg ./image_data/816.jpg 1.0
# 删除次数 2503
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/816.jpg ./image_data/840.jpg 1.0
# 删除次数 2504
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/840.jpg ./image_data/864.jpg 1.0
# 删除次数 2505
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/864.jpg ./image_data/888.jpg 1.0
# 删除次数 2506
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/888.jpg ./image_data/912.jpg 1.0
# 删除次数 2507
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/912.jpg ./image_data/936.jpg 1.0
# 删除次数 2508
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/936.jpg ./image_data/960.jpg 1.0
# 删除次数 2509
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/960.jpg ./image_data/984.jpg 1.0
# 删除次数 2510
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/984.jpg ./image_data/1008.jpg 1.0
# 删除次数 2511
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1008.jpg ./image_data/1032.jpg 1.0
# 删除次数 2512
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1032.jpg ./image_data/1056.jpg 1.0
# 删除次数 2513
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1056.jpg ./image_data/1080.jpg 1.0
# 删除次数 2514
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1080.jpg ./image_data/1104.jpg 1.0
# 删除次数 2515
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1104.jpg ./image_data/1128.jpg 1.0
# 删除次数 2516
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1128.jpg ./image_data/1152.jpg 1.0
# 删除次数 2517
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1152.jpg ./image_data/1176.jpg 1.0
# 删除次数 2518
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1176.jpg ./image_data/1200.jpg 1.0
# 删除次数 2519
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1200.jpg ./image_data/1224.jpg 1.0
# 删除次数 2520
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1224.jpg ./image_data/1248.jpg 1.0
# 删除次数 2521
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1248.jpg ./image_data/1272.jpg 1.0
# 删除次数 2522
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1272.jpg ./image_data/1296.jpg 1.0
# 删除次数 2523
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1296.jpg ./image_data/1320.jpg 1.0
# 删除次数 2524
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1320.jpg ./image_data/1344.jpg 1.0
# 删除次数 2525
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1344.jpg ./image_data/1368.jpg 1.0
# 删除次数 2526
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1368.jpg ./image_data/1392.jpg 1.0
# 删除次数 2527
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1392.jpg ./image_data/1416.jpg 1.0
# 删除次数 2528
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1416.jpg ./image_data/1440.jpg 1.0
# 删除次数 2529
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1440.jpg ./image_data/1464.jpg 1.0
# 删除次数 2530
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1464.jpg ./image_data/1488.jpg 1.0
# 删除次数 2531
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1488.jpg ./image_data/1512.jpg 1.0
# 删除次数 2532
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1512.jpg ./image_data/1536.jpg 1.0
# 删除次数 2533
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1536.jpg ./image_data/1560.jpg 1.0
# 删除次数 2534
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1560.jpg ./image_data/1584.jpg 1.0
# 删除次数 2535
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1584.jpg ./image_data/1608.jpg 1.0
# 删除次数 2536
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1608.jpg ./image_data/1632.jpg 1.0
# 删除次数 2537
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1632.jpg ./image_data/1656.jpg 1.0
# 删除次数 2538
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1656.jpg ./image_data/1680.jpg 1.0
# 删除次数 2539
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1680.jpg ./image_data/1704.jpg 1.0
# 删除次数 2540
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1704.jpg ./image_data/1728.jpg 1.0
# 删除次数 2541
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1728.jpg ./image_data/1752.jpg 1.0
# 删除次数 2542
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1752.jpg ./image_data/1776.jpg 1.0
# 删除次数 2543
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1776.jpg ./image_data/1800.jpg 1.0
# 删除次数 2544
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1800.jpg ./image_data/1824.jpg 1.0
# 删除次数 2545
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1824.jpg ./image_data/1848.jpg 1.0
# 删除次数 2546
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1848.jpg ./image_data/1872.jpg 1.0
# 删除次数 2547
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1872.jpg ./image_data/1896.jpg 1.0
# 删除次数 2548
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1896.jpg ./image_data/1920.jpg 1.0
# 删除次数 2549
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1920.jpg ./image_data/1944.jpg 1.0
# 删除次数 2550
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1944.jpg ./image_data/1968.jpg 1.0
# 删除次数 2551
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1968.jpg ./image_data/1992.jpg 1.0
# 删除次数 2552
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/1992.jpg ./image_data/2016.jpg 1.0
# 删除次数 2553
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2016.jpg ./image_data/2040.jpg 1.0
# 删除次数 2554
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2040.jpg ./image_data/2064.jpg 1.0
# 删除次数 2555
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2064.jpg ./image_data/2088.jpg 1.0
# 删除次数 2556
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2088.jpg ./image_data/2112.jpg 1.0
# 删除次数 2557
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2112.jpg ./image_data/2136.jpg 1.0
# 删除次数 2558
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2136.jpg ./image_data/2160.jpg 1.0
# 删除次数 2559
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2160.jpg ./image_data/2184.jpg 1.0
# 删除次数 2560
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2184.jpg ./image_data/2208.jpg 1.0
# 删除次数 2561
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2208.jpg ./image_data/2232.jpg 1.0
# 删除次数 2562
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2232.jpg ./image_data/2256.jpg 1.0
# 删除次数 2563
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2256.jpg ./image_data/2280.jpg 1.0
# 删除次数 2564
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2280.jpg ./image_data/2304.jpg 1.0
# 删除次数 2565
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2304.jpg ./image_data/2328.jpg 1.0
# 删除次数 2566
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2328.jpg ./image_data/2352.jpg 1.0
# 删除次数 2567
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2352.jpg ./image_data/2376.jpg 1.0
# 删除次数 2568
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2376.jpg ./image_data/2400.jpg 1.0
# 删除次数 2569
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2400.jpg ./image_data/2424.jpg 1.0
# 删除次数 2570
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2424.jpg ./image_data/2448.jpg 1.0
# 删除次数 2571
# <class 'numpy.ndarray'>
# (720, 1280, 3)
# ./image_data/2448.jpg ./image_data/2472.jpg 1.0
# 删除次数 2572

# %%
path = r'./image_data/'
img_files=[]
for rootdir, _, files in os.walk(path):
    files.sort(key=lambda x:int(x[:-4]))
for file in files:
     if file.endswith('.jpg'):
        img_files.append(os.path.join(rootdir, file))

img_files
# Out:
# ['./image_data/24.jpg',
#  './image_data/48.jpg',
#  './image_data/72.jpg',
#  './image_data/120.jpg',
#  './image_data/144.jpg',
#  './image_data/168.jpg',
#  './image_data/216.jpg',
#  './image_data/240.jpg',
#  './image_data/264.jpg',
#  './image_data/432.jpg',
#  './image_data/792.jpg',
#  './image_data/816.jpg',
#  './image_data/888.jpg',
#  './image_data/936.jpg',
#  './image_data/960.jpg',
#  './image_data/984.jpg',
#  './image_data/1056.jpg',
#  './image_data/1848.jpg',
#  './image_data/1872.jpg',
#  './image_data/1896.jpg',
#  './image_data/2448.jpg',
#  './image_data/2472.jpg']
