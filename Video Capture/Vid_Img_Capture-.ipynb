# %%
# 视频分解图片
# 1 load 2 info 3 parse 4 imshow imwrite
import cv2
import os
# 获取一个视频打开cap 参数1 file name
#cap = cv2.VideoCapture("2.mp4")
#cap = cv2.VideoCapture(0, cv2.CAP_DSHOW) # 摄像头截取
cap = cv2.VideoCapture('./video/lift.mp4')
isOpened = cap.isOpened # 判断是否打开‘
print(isOpened)
# 获取信息 宽高
n_frame = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print('总帧数：',n_frame) # 整个视频的总帧数
fps = cap.get(cv2.CAP_PROP_FPS) # 帧率 每秒展示多少张图片
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) # w
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)) # h
print('帧数、宽度、高度分别为：',fps,width,height) # 帧率 宽 高
i = 0 # 记录读取多少帧

frameFrequency = 24 # 每frameFrequency保存一张图片

while(isOpened):
    
    # 结束标志是否读取到最后一帧
    if i == n_frame:
        break
    else:
        i = i+1
    (flag,frame) = cap.read() # read方法 读取每一张 flag是否读取成功 frame 读取内容
    fileName = str(i)+'.jpg' # 名字累加
    # True表示读取成功 进行·写入
    # if 判断需要有冒号
    #if flag == True:
    outPutDirName = './image_data/' # 设置保存路径
    if not os.path.exists(outPutDirName):
        # 如果文件目录不存在则创建目录
        os.makedirs(outPutDirName)
    if i % frameFrequency == 0:
        print(fileName)
        cv2.imwrite(outPutDirName+fileName,frame,[cv2.IMWRITE_JPEG_QUALITY,100])# 质量控制 100最高
print('end!')
# Out:
# <built-in method isOpened of cv2.VideoCapture object at 0x000002581224C2F0>
# 总帧数： 2472
# 帧数、宽度、高度分别为： 29.97002997002997 1280 720
# 24.jpg
# 48.jpg
# 72.jpg
# 96.jpg
# 120.jpg
# 144.jpg
# 168.jpg
# 192.jpg
# 216.jpg
# 240.jpg
# 264.jpg
# 288.jpg
# 312.jpg
# 336.jpg
# 360.jpg
# 384.jpg
# 408.jpg
# 432.jpg
# 456.jpg
# 480.jpg
# 504.jpg
# 528.jpg
# 552.jpg
# 576.jpg
# 600.jpg
# 624.jpg
# 648.jpg
# 672.jpg
# 696.jpg
# 720.jpg
# 744.jpg
# 768.jpg
# 792.jpg
# 816.jpg
# 840.jpg
# 864.jpg
# 888.jpg
# 912.jpg
# 936.jpg
# 960.jpg
# 984.jpg
# 1008.jpg
# 1032.jpg
# 1056.jpg
# 1080.jpg
# 1104.jpg
# 1128.jpg
# 1152.jpg
# 1176.jpg
# 1200.jpg
# 1224.jpg
# 1248.jpg
# 1272.jpg
# 1296.jpg
# 1320.jpg
# 1344.jpg
# 1368.jpg
# 1392.jpg
# 1416.jpg
# 1440.jpg
# 1464.jpg
# 1488.jpg
# 1512.jpg
# 1536.jpg
# 1560.jpg
# 1584.jpg
# 1608.jpg
# 1632.jpg
# 1656.jpg
# 1680.jpg
# 1704.jpg
# 1728.jpg
# 1752.jpg
# 1776.jpg
# 1800.jpg
# 1824.jpg
# 1848.jpg
# 1872.jpg
# 1896.jpg
# 1920.jpg
# 1944.jpg
# 1968.jpg
# 1992.jpg
# 2016.jpg
# 2040.jpg
# 2064.jpg
# 2088.jpg
# 2112.jpg
# 2136.jpg
# 2160.jpg
# 2184.jpg
# 2208.jpg
# 2232.jpg
# 2256.jpg
# 2280.jpg
# 2304.jpg
# 2328.jpg
# 2352.jpg
# 2376.jpg
# 2400.jpg
# 2424.jpg
# 2448.jpg
# 2472.jpg
# end!

# %%
import os
import cv2
import numpy as np 
#from skimage import compare_ssim
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import structural_similarity
#from skimage.measure import compare_ssim
'''相邻两个文件比较相似度，相似就把第二个加到新列表(删除列表）里，然后进行新列表去重，统一删除。
　　例如：有文件1-10，首先1和2相比较，若相似，则把2加入到新列表里，再接着2和3相比较，若不相似，则继续进行3和4比较...一直比到最后，然后删除新列表里的图片
   只对于连续图片（例一个视频里截下的图片）准确率也较高，其效率高'''
def delete(filename1):
    os.remove(filename1)
if __name__ == '__main__':
    path = r'./image_data/' # 文件所在路径
    img_path = path
    imgs_n = [] # 新建的删除列表
    # i = 0 # 用来统计删了第几张图片
    # img_files = [os.path.join(rootdir, file) for rootdir, _, files in os.walk(path) for file in files if
    #              (file.endswith('.jpg'))] 
    img_files=[]
    for rootdir, _, files in os.walk(path):
        files.sort(key=lambda x:int(x[:-4]))
    for file in files:
         if file.endswith('.jpg'):
            img_files.append(os.path.join(rootdir, file))
   
    for currIndex, filename in enumerate(img_files):
        if not os.path.exists(img_files[currIndex]):
            print('not exist', img_files[currIndex])
            break
        img = cv2.imread(img_files[currIndex])
        img1 = cv2.imread(img_files[currIndex + 1])
        # img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        # https://cloud.tencent.com/developer/section/1414961 开发者手册链接
        # 本程序最核心的代码
        # skimage.measure.compare_ssim（X，Y，...）
        # 计算两幅图像之间的平均结构相似性指数
        #ssim = ssim(img, img1,multichannel=True,win_size=7)
        ssim=structural_similarity(img, img1,channel_axis=-1)
        # 相似度大于0.9就加入删除列表
        if ssim > 0.93:
            imgs_n.append(img_files[currIndex + 1]) # 加入新建删除列表
            i = i+1 # 每加入一个就会删除
            print(img_files[currIndex], img_files[currIndex + 1], ssim)
            print('删除次数', i)
        # 否则不删除，给出两图片的相似度
        else:
            print('small_ssim',img_files[currIndex], img_files[currIndex + 1], ssim)
        currIndex += 1
        if currIndex >= len(img_files)-1:
            break
    for image in imgs_n:
        delete(image)
# Out:
# small_ssim ./image_data/24.jpg ./image_data/48.jpg 0.8995970298222297
# small_ssim ./image_data/48.jpg ./image_data/72.jpg 0.9209351520152098
# ./image_data/72.jpg ./image_data/96.jpg 0.9314691738814508
# 删除次数 2473
# small_ssim ./image_data/96.jpg ./image_data/120.jpg 0.9056357072500892
# small_ssim ./image_data/120.jpg ./image_data/144.jpg 0.8193314116544528
# small_ssim ./image_data/144.jpg ./image_data/168.jpg 0.8288022366041646
# ./image_data/168.jpg ./image_data/192.jpg 0.9580935360599558
# 删除次数 2474
# small_ssim ./image_data/192.jpg ./image_data/216.jpg 0.9279857903641098
# small_ssim ./image_data/216.jpg ./image_data/240.jpg 0.8788031844536125
# small_ssim ./image_data/240.jpg ./image_data/264.jpg 0.9022583484477241
# ./image_data/264.jpg ./image_data/288.jpg 0.9570751355309035
# 删除次数 2475
# ./image_data/288.jpg ./image_data/312.jpg 0.9436551361402871
# 删除次数 2476
# ./image_data/312.jpg ./image_data/336.jpg 0.936785726834454
# 删除次数 2477
# ./image_data/336.jpg ./image_data/360.jpg 0.9514685933215471
# 删除次数 2478
# ./image_data/360.jpg ./image_data/384.jpg 0.9545615416101936
# 删除次数 2479
# ./image_data/384.jpg ./image_data/408.jpg 0.9506395133945608
# 删除次数 2480
# small_ssim ./image_data/408.jpg ./image_data/432.jpg 0.9149209390211199
# ./image_data/432.jpg ./image_data/456.jpg 0.9470728787824073
# 删除次数 2481
# ./image_data/456.jpg ./image_data/480.jpg 0.9577303743170095
# 删除次数 2482
# ./image_data/480.jpg ./image_data/504.jpg 0.9593405533620168
# 删除次数 2483
# ./image_data/504.jpg ./image_data/528.jpg 0.9691497113148104
# 删除次数 2484
# ./image_data/528.jpg ./image_data/552.jpg 0.9516159459649279
# 删除次数 2485
# ./image_data/552.jpg ./image_data/576.jpg 0.9724181685046211
# 删除次数 2486
# ./image_data/576.jpg ./image_data/600.jpg 0.9702810324487746
# 删除次数 2487
# ./image_data/600.jpg ./image_data/624.jpg 0.9605214102714501
# 删除次数 2488
# ./image_data/624.jpg ./image_data/648.jpg 0.9591785396756034
# 删除次数 2489
# ./image_data/648.jpg ./image_data/672.jpg 0.9634560097601353
# 删除次数 2490
# ./image_data/672.jpg ./image_data/696.jpg 0.973461662281928
# 删除次数 2491
# ./image_data/696.jpg ./image_data/720.jpg 0.9822316682217983
# 删除次数 2492
# ./image_data/720.jpg ./image_data/744.jpg 0.9867576358412368
# 删除次数 2493
# ./image_data/744.jpg ./image_data/768.jpg 0.9494880282075927
# 删除次数 2494
# small_ssim ./image_data/768.jpg ./image_data/792.jpg 0.8701852652920495
# small_ssim ./image_data/792.jpg ./image_data/816.jpg 0.9084614255542244
# ./image_data/816.jpg ./image_data/840.jpg 0.9407445347282986
# 删除次数 2495
# ./image_data/840.jpg ./image_data/864.jpg 0.9378775980582915
# 删除次数 2496
# small_ssim ./image_data/864.jpg ./image_data/888.jpg 0.9166444001251315
# ./image_data/888.jpg ./image_data/912.jpg 0.9397101062675405
# 删除次数 2497
# small_ssim ./image_data/912.jpg ./image_data/936.jpg 0.9266078123079803
# small_ssim ./image_data/936.jpg ./image_data/960.jpg 0.9079079047909758
# small_ssim ./image_data/960.jpg ./image_data/984.jpg 0.9196019735295398
# ./image_data/984.jpg ./image_data/1008.jpg 0.9329355914862356
# 删除次数 2498
# ./image_data/1008.jpg ./image_data/1032.jpg 0.9495488337951712
# 删除次数 2499
# small_ssim ./image_data/1032.jpg ./image_data/1056.jpg 0.9245462288884801
# ./image_data/1056.jpg ./image_data/1080.jpg 0.9532446991458379
# 删除次数 2500
# ./image_data/1080.jpg ./image_data/1104.jpg 0.9487626468285435
# 删除次数 2501
# ./image_data/1104.jpg ./image_data/1128.jpg 0.9697533516905619
# 删除次数 2502
# ./image_data/1128.jpg ./image_data/1152.jpg 0.9901809326736456
# 删除次数 2503
# ./image_data/1152.jpg ./image_data/1176.jpg 0.9887792279534033
# 删除次数 2504
# ./image_data/1176.jpg ./image_data/1200.jpg 0.9908121964961033
# 删除次数 2505
# ./image_data/1200.jpg ./image_data/1224.jpg 0.9902349299570249
# 删除次数 2506
# ./image_data/1224.jpg ./image_data/1248.jpg 0.9883094920755333
# 删除次数 2507
# ./image_data/1248.jpg ./image_data/1272.jpg 0.9868573036113474
# 删除次数 2508
# ./image_data/1272.jpg ./image_data/1296.jpg 0.9726846320583635
# 删除次数 2509
# ./image_data/1296.jpg ./image_data/1320.jpg 0.9815836913254085
# 删除次数 2510
# ./image_data/1320.jpg ./image_data/1344.jpg 0.9854901696216576
# 删除次数 2511
# ./image_data/1344.jpg ./image_data/1368.jpg 0.9869302685344433
# 删除次数 2512
# ./image_data/1368.jpg ./image_data/1392.jpg 0.991914251855058
# 删除次数 2513
# ./image_data/1392.jpg ./image_data/1416.jpg 0.9859447620659142
# 删除次数 2514
# ./image_data/1416.jpg ./image_data/1440.jpg 0.9813246501396248
# 删除次数 2515
# ./image_data/1440.jpg ./image_data/1464.jpg 0.9754410205963442
# 删除次数 2516
# ./image_data/1464.jpg ./image_data/1488.jpg 0.9750132547834532
# 删除次数 2517
# ./image_data/1488.jpg ./image_data/1512.jpg 0.9686115498128053
# 删除次数 2518
# ./image_data/1512.jpg ./image_data/1536.jpg 0.9861676262467349
# 删除次数 2519
# ./image_data/1536.jpg ./image_data/1560.jpg 0.9663035704270291
# 删除次数 2520
# ./image_data/1560.jpg ./image_data/1584.jpg 0.9422331800229798
# 删除次数 2521
# ./image_data/1584.jpg ./image_data/1608.jpg 0.9367810020503091
# 删除次数 2522
# ./image_data/1608.jpg ./image_data/1632.jpg 0.9364862596159895
# 删除次数 2523
# ./image_data/1632.jpg ./image_data/1656.jpg 0.969271826701036
# 删除次数 2524
# ./image_data/1656.jpg ./image_data/1680.jpg 0.9646214152359457
# 删除次数 2525
# ./image_data/1680.jpg ./image_data/1704.jpg 0.9745562723859656
# 删除次数 2526
# ./image_data/1704.jpg ./image_data/1728.jpg 0.9453945357812589
# 删除次数 2527
# ./image_data/1728.jpg ./image_data/1752.jpg 0.9527066715505085
# 删除次数 2528
# ./image_data/1752.jpg ./image_data/1776.jpg 0.9398711462491796
# 删除次数 2529
# ./image_data/1776.jpg ./image_data/1800.jpg 0.9516606450098788
# 删除次数 2530
# ./image_data/1800.jpg ./image_data/1824.jpg 0.9636132753512183
# 删除次数 2531
# small_ssim ./image_data/1824.jpg ./image_data/1848.jpg 0.595597526081442
# small_ssim ./image_data/1848.jpg ./image_data/1872.jpg 0.5821222448093042
# small_ssim ./image_data/1872.jpg ./image_data/1896.jpg 0.4595278694181501
# ./image_data/1896.jpg ./image_data/1920.jpg 0.9999991371520623
# 删除次数 2532
# ./image_data/1920.jpg ./image_data/1944.jpg 0.9847330733480962
# 删除次数 2533
# ./image_data/1944.jpg ./image_data/1968.jpg 0.9999917658518985
# 删除次数 2534
# ./image_data/1968.jpg ./image_data/1992.jpg 0.9999752111871908
# 删除次数 2535
# ./image_data/1992.jpg ./image_data/2016.jpg 1.0
# 删除次数 2536
# ./image_data/2016.jpg ./image_data/2040.jpg 1.0
# 删除次数 2537
# ./image_data/2040.jpg ./image_data/2064.jpg 0.9999751959810302
# 删除次数 2538
# ./image_data/2064.jpg ./image_data/2088.jpg 0.9913763413674377
# 删除次数 2539
# ./image_data/2088.jpg ./image_data/2112.jpg 0.9999916859220557
# 删除次数 2540
# ./image_data/2112.jpg ./image_data/2136.jpg 0.9999998680328646
# 删除次数 2541
# ./image_data/2136.jpg ./image_data/2160.jpg 1.0
# 删除次数 2542
# ./image_data/2160.jpg ./image_data/2184.jpg 1.0
# 删除次数 2543
# ./image_data/2184.jpg ./image_data/2208.jpg 0.9999998132180336
# 删除次数 2544
# ./image_data/2208.jpg ./image_data/2232.jpg 0.9999997145988879
# 删除次数 2545
# ./image_data/2232.jpg ./image_data/2256.jpg 0.9932985603199033
# 删除次数 2546
# ./image_data/2256.jpg ./image_data/2280.jpg 0.9999948554696659
# 删除次数 2547
# ./image_data/2280.jpg ./image_data/2304.jpg 1.0
# 删除次数 2548
# ./image_data/2304.jpg ./image_data/2328.jpg 1.0
# 删除次数 2549
# ./image_data/2328.jpg ./image_data/2352.jpg 1.0
# 删除次数 2550
# ./image_data/2352.jpg ./image_data/2376.jpg 0.9999998646228486
# 删除次数 2551
# ./image_data/2376.jpg ./image_data/2400.jpg 0.9999759350650138
# 删除次数 2552
# ./image_data/2400.jpg ./image_data/2424.jpg 0.9885203315096347
# 删除次数 2553
# small_ssim ./image_data/2424.jpg ./image_data/2448.jpg 0.5295747546053934
# small_ssim ./image_data/2448.jpg ./image_data/2472.jpg 0.7983468094802258

# %%
path = r'./image_data/'
img_files=[]
for rootdir, _, files in os.walk(path):
    files.sort(key=lambda x:int(x[:-4]))
for file in files:
     if file.endswith('.jpg'):
        img_files.append(os.path.join(rootdir, file))

img_files
# Out:
# ['./image_data/24.jpg',
#  './image_data/48.jpg',
#  './image_data/72.jpg',
#  './image_data/120.jpg',
#  './image_data/144.jpg',
#  './image_data/168.jpg',
#  './image_data/216.jpg',
#  './image_data/240.jpg',
#  './image_data/264.jpg',
#  './image_data/432.jpg',
#  './image_data/792.jpg',
#  './image_data/816.jpg',
#  './image_data/888.jpg',
#  './image_data/936.jpg',
#  './image_data/960.jpg',
#  './image_data/984.jpg',
#  './image_data/1056.jpg',
#  './image_data/1848.jpg',
#  './image_data/1872.jpg',
#  './image_data/1896.jpg',
#  './image_data/2448.jpg',
#  './image_data/2472.jpg']
